# %%
import numpy as np
import cv2
import os

import Face_Recognition as fr
print (fr)



face_recognizer=cv2.face.LBPHFaceRecognizer_create()
face_recognizer.read(r'C:\Users\Bryan Devadatha\Desktop\my projects\Face-Recognition-LBPH\TrainingData.yml')    #Give path of where trainingData.yml is saved

cap=cv2.VideoCapture('vid1.mp4')   #If you want to recognise face from a video then replace  with video path

name={0:"Bryan",1:"Zucc"}    #Change names accordingly.  If you want to recognize only one person then write:- name={0:"name"} thats all. Dont write for id number 1.
while True:
    ret,test_img=cap.read()
    faces_detected,gray_img=fr.facedetection(test_img)
    print("face Detected: ",faces_detected)
    for (x,y,w,h) in faces_detected:
        cv2.rectangle(test_img,(x,y),(x+w,y+h),(0,255,0),thickness=5)

    
    
    for face in faces_detected:
        (x,y,w,h)=face
        roi_gray=gray_img[y:y+h,x:x+h]
        label,confidence=face_recognizer.predict(roi_gray)
        print ("Confidence :",confidence)
        print("label :",label)
        fr.draw_rect(test_img,face)
        predicted_name=name[label]
        fr.put_text(test_img,predicted_name,x,y)

    resized_img=cv2.resize(test_img,(1000,700))

    cv2.imshow("face detection ", resized_img)
    if cv2.waitKey(10)==ord('q'):
        break
# Out:
# <module 'Face_Recognition' from 'C:\\Users\\Bryan Devadatha\\Desktop\\my projects\\Face-Recognition-master\\Face_Recognition.py'>
# face Detected:  [[167  56  92  92]]
# Confidence : 112.10070042387484
# label : 0
# face Detected:  [[163  54  95  95]]
# Confidence : 115.1634416999864
# label : 0
# face Detected:  [[163  56  91  91]]
# Confidence : 111.76664279737568
# label : 0
# face Detected:  [[160  53  95  95]]
# Confidence : 114.63961878873148
# label : 0
# face Detected:  [[160  53  95  95]]
# Confidence : 114.71564622005812
# label : 0
# face Detected:  [[161  56  90  90]]
# Confidence : 111.97587116014178
# label : 0
# face Detected:  [[157  54  95  95]]
# Confidence : 115.49673026208943
# label : 0
# face Detected:  [[160  57  92  92]]
# Confidence : 110.32988103618881
# label : 0
# face Detected:  [[164  62  83  83]]
# Confidence : 124.60275739836078
# label : 0
# face Detected:  [[161  61  86  86]]
# Confidence : 122.53458387986782
# label : 0
# face Detected:  ()
# face Detected:  ()
# face Detected:  ()
# face Detected:  ()
# face Detected:  ()
# face Detected:  ()
# face Detected:  ()
# face Detected:  ()
# face Detected:  ()
# face Detected:  ()
# face Detected:  ()
# face Detected:  ()
# face Detected:  ()
# face Detected:  ()
# face Detected:  ()
# face Detected:  [[160  48  97  97]]
# Confidence : 124.46493939112142
# label : 0
# face Detected:  [[168  49  98  98]]
# Confidence : 110.52462639052094
# label : 0
# face Detected:  ()
# face Detected:  ()
# face Detected:  ()
# face Detected:  ()
# face Detected:  [[196  63  78  78]]
# Confidence : 122.75784824409547
# label : 0
# face Detected:  [[195  60  82  82]]
# Confidence : 114.72807806923495
# label : 0
# face Detected:  [[193  57  87  87]]
# Confidence : 114.58099125084391
# label : 0
# face Detected:  [[195  58  84  84]]
# Confidence : 111.62802648845046
# label : 0
# face Detected:  [[190  53  93  93]]
# Confidence : 115.15672302719061
# label : 0
# face Detected:  [[196  57  86  86]]
# Confidence : 117.06041324723354
# label : 0
# face Detected:  [[194  59  84  84]]
# Confidence : 118.69206998723855
# label : 0
# face Detected:  [[192  58  87  87]]
# Confidence : 121.578732512522
# label : 0
# face Detected:  [[192  59  85  85]]
# Confidence : 120.80994730571356
# label : 0
# face Detected:  [[190  62  86  86]]
# Confidence : 119.06168316477009
# label : 0
# face Detected:  [[189  62  85  85]]
# Confidence : 115.46909379108716
# label : 0
# face Detected:  [[188  61  84  84]]
# Confidence : 114.20846300304306
# label : 0
# face Detected:  [[185  59  86  86]]
# Confidence : 115.8334294056851
# label : 0
# face Detected:  [[184  58  88  88]]
# Confidence : 114.70885378771753
# label : 0
# face Detected:  [[186  58  86  86]]
# Confidence : 115.86652607148125
# label : 0
# face Detected:  [[184  57  88  88]]
# Confidence : 116.73578252513411
# label : 0
# face Detected:  [[187  58  83  83]]
# Confidence : 114.32296873220135
# label : 0
# face Detected:  [[187  57  84  84]]
# Confidence : 113.26035112532914
# label : 0
# face Detected:  [[187  57  84  84]]
# Confidence : 113.30718726131097
# label : 0
# face Detected:  [[188  56  82  82]]
# Confidence : 112.23753109237435
# label : 0
# face Detected:  [[189  54  84  84]]
# Confidence : 111.2106818248792
# label : 0
# face Detected:  [[189  52  86  86]]
# Confidence : 111.84493985450551
# label : 0
# face Detected:  [[190  51  88  88]]
# Confidence : 110.97131395165208
# label : 0
# face Detected:  [[189  51  88  88]]
# Confidence : 112.17424084537511
# label : 0
# face Detected:  [[191  51  88  88]]
# Confidence : 112.88887777818151
# label : 0
# face Detected:  [[192  49  90  90]]
# Confidence : 109.61805713728235
# label : 0
# face Detected:  [[195  49  88  88]]
# Confidence : 111.22407921029166
# label : 0
# face Detected:  [[196  48  89  89]]
# Confidence : 113.5845178028553
# label : 0
# face Detected:  [[196  48  89  89]]
# Confidence : 113.71951049119744
# label : 0
# face Detected:  [[200  50  87  87]]
# Confidence : 114.76546809355885
# label : 0
# face Detected:  [[201  49  90  90]]
# Confidence : 107.59832233343101
# label : 0
# face Detected:  [[201  52  92  92]]
# Confidence : 109.15018568914493
# label : 0
# face Detected:  [[205  53  90  90]]
# Confidence : 104.96551737539792
# label : 0
# face Detected:  [[204  53  93  93]]
# Confidence : 105.07684548948194
# label : 0
# face Detected:  [[208  56  91  91]]
# Confidence : 101.67315278062183
# label : 0
# face Detected:  [[213  57  90  90]]
# Confidence : 101.31441954971606
# label : 0
# face Detected:  [[213  55  95  95]]
# Confidence : 103.02857675108154
# label : 0
# face Detected:  [[218  59  91  91]]
# Confidence : 101.7537645314488
# label : 0
# face Detected:  [[218  59  91  91]]
# Confidence : 101.93964097426436
# label : 0
# face Detected:  [[219  60  96  96]]
# Confidence : 105.44428546869597
# label : 0
# face Detected:  [[224  63  94  94]]
# Confidence : 105.13905144303712
# label : 0
# face Detected:  [[218  60 103 103]]
# Confidence : 106.59687610481997
# label : 0
# face Detected:  ()
# face Detected:  ()
# face Detected:  ()
# face Detected:  ()
# face Detected:  ()
